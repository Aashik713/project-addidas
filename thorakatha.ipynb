# %%
import pandas as pd

# %%
df=pd.read_csv("amazon.csv")

# %%
dd.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'discount_percentage', 'rating'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
dd=dd.drop("review_content",axis='columns')

# %%
dd.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#   discount_percentage rating
# 0                 64%    4.2
# 1                 43%    4.0
# 2                 90%    3.9
# ...

# %%
dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   discount_percentage  1465 non-null   object
#  5   rating               1465 non-null   object
# dtypes: object(6)
# memory usage: 68.8+ KB

# %%
dd.shape
# Out:
# (1465, 6)

# %%
dd.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B07JW9H4J1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        discount_percentage rating
# count                 1465   1465
# unique                  92     28
# top                    50%    4.1
# freq                    56    244

# %%
dd.nunique()
# Out:
# product_id             1351
# product_name           1337
# category                211
# discounted_price        550
# discount_percentage      92
# rating                   28
# dtype: int64

# %% [markdown]
# ## Based on product name and id

# %%
dd['product_name'].value_counts()

#most bought product is a watch
# Out:
# Fire-Boltt Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240*280 Pixel High Resolution                           5
# Fire-Boltt Phoenix Smart Watch with Bluetooth Calling 1.3",120+ Sports Modes, 240*240 PX High Res with SpO2, Heart Rate Monitoring & IP67 Rating                                    4
# Wayona Nylon Braided USB to Lightning Fast Charging and Data Sync Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini (3 FT Pack of 1, Grey)                  3
# MI Braided USB Type-C Cable for Charging Adapter (Red)                                                                                                                              3
# Amazonbasics Nylon Braided Usb-C To Lightning Cable, Fast Charging Mfi Certified Smartphone, Iphone Charger (6-Foot, Dark Grey)                                                     3
# ...

# %% [markdown]
# # Based on catagory

# %%
dd['category'].value_counts()
#usb cables demand>>>> ==>> increase production 
#elec cam ,battery,...demand<<<< ===>>> halt or limit production to prevent loss
# Out:
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                                          233
# Electronics|WearableTechnology|SmartWatches                                                                                 76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                                        68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                               63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                                                52
#                                                                                                                           ...
# Electronics|Cameras&Photography|Accessories|Batteries&Chargers|BatteryChargers                                               1
# ...

# %%
dd.nunique()
# Out:
# product_id             1351
# product_name           1337
# category                211
# discounted_price        550
# discount_percentage      92
# rating                   28
# dtype: int64

# %%
for i in range(1465):
    dd["discount_percentage"][i]=dd["discount_percentage"][i].replace('%',"")
    #dd["discount_percentage"][i]=dd["discounted_price"][i].replace(',',"")
dd["discount_percentage"]= pd.to_numeric(dd["discount_percentage"])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_456\3839475308.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dd["discount_percentage"][i]=dd["discount_percentage"][i].replace('%',"")

# %%
ddcab=dd.loc[dd["category"]=="Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables"] 
ddcab
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 990   B09CMP1SC8  Ambrane 2 in 1 Type-C & Micro USB Cable with 6...
# 992   B09YLXYP7Y  Ambrane 60W / 3A Fast Charging Output Cable wi...
# 1000  B0B2DJDCPX  SWAPKART Fast Charging Cable and Data Sync USB...
# 1010  B07GVGTSLN  Wayona Usb Type C Fast Charger Cable Fast Char...
# 1018  B0BMXMLSMM  Lapster 65W compatible for OnePlus Dash Warp C...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %%
ddcab["discount_percentage"].sum()
# Out:
# 13835

# %%
ddcabmax=ddcab.loc[ddcab["discount_percentage"]==ddcab['discount_percentage'].max()]
ddcabmax
# Out:
#    product_id                                       product_name  \
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                             category  discounted_price  \
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
#
#    discount_percentage rating
# 2                   90    3.9

# %%
ddcabmin=ddcab.loc[ddcab["discount_percentage"]==ddcab['discount_percentage'].min()]
ddcabmin
# Out:
#      product_id                                       product_name  \
# 33   B008FWZGSG  Samsung Original Type C to C Cable - 3.28 Feet...
# 833  B008FWZGSG  Samsung Original Type C to C Cable - 3.28 Feet...
#
#                                               category  discounted_price  \
# 33   Computers&Accessories|Accessories&Peripherals|...             599.0
# 833  Computers&Accessories|Accessories&Peripherals|...             599.0
#
#      discount_percentage rating
# 33                     0    4.3
# 833                    0    4.3

# %%
(ddcabmin['discounted_price'].sum())/(ddcab["discount_percentage"].sum())
# Out:
# 0.08659197687025659

# %%
ddcabmax['discounted_price'].sum()
# Out:
# 199.0

# %% [markdown]
# # Based on discount

# %%
s=pd.DataFrame()
dd.loc[dd["discount_percentage"]==0]
# Out:
#       product_id                                       product_name  \
# 33    B008FWZGSG  Samsung Original Type C to C Cable - 3.28 Feet...
# 138   B071VMP1Z4  LRIPL Compatible Sony Bravia LCD/led Remote Wo...
# 264   B09LQQYNZQ                           Realme Smart TV Stick 4K
# 321   B084872DQY  Mi 80 cm (32 inches) HD Ready Android Smart LE...
# 339   B0B3CPQ5PF  OnePlus Nord 2T 5G (Jade Fog, 8GB RAM, 128GB S...
# 340   B0B3CQBRB4  OnePlus Nord 2T 5G (Gray Shadow, 8GB RAM, 128G...
# 406   B0B3D39RKV  OnePlus Nord 2T 5G (Jade Fog, 12GB RAM, 256GB ...
# 466   B01F25X6RQ  Samsung Ehs64 Ehs64Avfwecinu Hands-Free Wired ...
# 539   B08BQ947H3  LIRAMARK Webcam Cover Slide, Ultra Thin Laptop...
# 616   B07KCMR8D6  Classmate Octane Neon- Blue Gel Pens(Pack of 5...
# 637   B0846D5CBP  Casio FX-991ES Plus-2nd Edition Scientific Cal...
# 703   B00R1P3B4O  Fujifilm Instax Mini Single Pack 10 Sheets Ins...
# 710   B08TDJNM3G  E-COSMOS 5V 1.2W Portable Flexible USB LED Lig...
# ...

# %%
ddmax=dd.loc[dd["discount_percentage"]==dd['discount_percentage'].max()]
ddmax
# Out:
#      product_id                                       product_name  \
# 695  B097C564GC  rts [2 Pack] Mini USB C Type C Adapter Plug, T...
#
#                                               category  discounted_price  \
# 695  Computers&Accessories|Accessories&Peripherals|...             294.0
#
#      discount_percentage rating
# 695                   94    4.3

# %%
ddmin=dd.loc[dd["discount_percentage"]==dd['discount_percentage'].min()]
ddmin
# Out:
#       product_id                                       product_name  \
# 33    B008FWZGSG  Samsung Original Type C to C Cable - 3.28 Feet...
# 138   B071VMP1Z4  LRIPL Compatible Sony Bravia LCD/led Remote Wo...
# 264   B09LQQYNZQ                           Realme Smart TV Stick 4K
# 321   B084872DQY  Mi 80 cm (32 inches) HD Ready Android Smart LE...
# 339   B0B3CPQ5PF  OnePlus Nord 2T 5G (Jade Fog, 8GB RAM, 128GB S...
# 340   B0B3CQBRB4  OnePlus Nord 2T 5G (Gray Shadow, 8GB RAM, 128G...
# 406   B0B3D39RKV  OnePlus Nord 2T 5G (Jade Fog, 12GB RAM, 256GB ...
# 466   B01F25X6RQ  Samsung Ehs64 Ehs64Avfwecinu Hands-Free Wired ...
# 539   B08BQ947H3  LIRAMARK Webcam Cover Slide, Ultra Thin Laptop...
# 616   B07KCMR8D6  Classmate Octane Neon- Blue Gel Pens(Pack of 5...
# 637   B0846D5CBP  Casio FX-991ES Plus-2nd Edition Scientific Cal...
# 703   B00R1P3B4O  Fujifilm Instax Mini Single Pack 10 Sheets Ins...
# 710   B08TDJNM3G  E-COSMOS 5V 1.2W Portable Flexible USB LED Lig...
# ...

# %%
ddmin["discounted_price"].sum()
# Out:
# 136590.0

# %%
ddmax["discounted_price"].sum()
# Out:
# 294.0

# %%
dd.loc[dd["discount_percentage"]==dd['discount_percentage'].max()]
# Out:
#      product_id                                       product_name  \
# 695  B097C564GC  rts [2 Pack] Mini USB C Type C Adapter Plug, T...
#
#                                               category  discounted_price  \
# 695  Computers&Accessories|Accessories&Peripherals|...             294.0
#
#      discount_percentage rating
# 695                   94    4.3

# %%
c=dd["category"].unique()
d=list()
for i in range(len(c)):
    s=0
    L=0
    for j in range(1465):
        if(dd["category"][j]==c[i]):
            s=s+dd["discount_percentage"][j]
            L+=1
    s=s/L
    d.append(s)
    print(c[i]," - ",s)
# Out:
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables  -  59.377682403433475
# Computers&Accessories|NetworkingDevices|NetworkAdapters|WirelessUSBAdapters  -  49.111111111111114
# Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables  -  59.791666666666664
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions  -  38.285714285714285
# Electronics|HomeTheater,TV&Video|Accessories|RemoteControls  -  59.51020408163265
# Electronics|HomeTheater,TV&Video|Televisions|StandardTelevisions  -  52.166666666666664
# Electronics|HomeTheater,TV&Video|Accessories|TVMounts,Stands&Turntables|TVWall&CeilingMounts  -  51.166666666666664
# Electronics|HomeTheater,TV&Video|Accessories|Cables|RCACables  -  50.5
# Electronics|HomeAudio|Accessories|SpeakerAccessories|Mounts  -  73.0
# Electronics|HomeTheater,TV&Video|Accessories|Cables|OpticalCables  -  46.333333333333336
# Electronics|HomeTheater,TV&Video|Projectors  -  42.666666666666664
# ...

# %%
dd['discounted_price'].value_counts()
# Out:
# 199.0     53
# 299.0     46
# 399.0     36
# 499.0     34
# 349.0     31
#           ..
# 190.0      1
# 570.0      1
# 1329.0     1
# 440.0      1
# 2863.0     1
# Name: discounted_price, Length: 550, dtype: int64

# %%
dd['discount_percentage'].value_counts()
#disc , count
# Out:
# 50    56
# 60    56
# 0     49
# 80    37
# 55    36
#       ..
# 2      2
# 7      2
# 94     1
# 89     1
# 9      1
# Name: discount_percentage, Length: 92, dtype: int64

# %%
dd["discount_percentage"].value_counts().sort_values()
# Out:
# 9      1
# 89     1
# 94     1
# 7      2
# 2      2
#       ..
# 55    36
# 80    37
# 0     49
# 60    56
# 50    56
# Name: discount_percentage, Length: 92, dtype: int64

# %%
dd.tail()
# Out:
#       product_id                                       product_name  \
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             379.0
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...            2280.0
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...            2219.0
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...            1399.0
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...            2863.0
#
#       discount_percentage rating
# 1460                   59      4
# 1461                   25    4.1
# ...

# %%
(dd["discount_percentage"]==0).value_counts()
#0 disc product
# Out:
# False    1416
# True       49
# Name: discount_percentage, dtype: int64

# %%
dd.loc[dd["discount_percentage"]==0]
# Out:
#       product_id                                       product_name  \
# 33    B008FWZGSG  Samsung Original Type C to C Cable - 3.28 Feet...
# 138   B071VMP1Z4  LRIPL Compatible Sony Bravia LCD/led Remote Wo...
# 264   B09LQQYNZQ                           Realme Smart TV Stick 4K
# 321   B084872DQY  Mi 80 cm (32 inches) HD Ready Android Smart LE...
# 339   B0B3CPQ5PF  OnePlus Nord 2T 5G (Jade Fog, 8GB RAM, 128GB S...
# 340   B0B3CQBRB4  OnePlus Nord 2T 5G (Gray Shadow, 8GB RAM, 128G...
# 406   B0B3D39RKV  OnePlus Nord 2T 5G (Jade Fog, 12GB RAM, 256GB ...
# 466   B01F25X6RQ  Samsung Ehs64 Ehs64Avfwecinu Hands-Free Wired ...
# 539   B08BQ947H3  LIRAMARK Webcam Cover Slide, Ultra Thin Laptop...
# 616   B07KCMR8D6  Classmate Octane Neon- Blue Gel Pens(Pack of 5...
# 637   B0846D5CBP  Casio FX-991ES Plus-2nd Edition Scientific Cal...
# 703   B00R1P3B4O  Fujifilm Instax Mini Single Pack 10 Sheets Ins...
# 710   B08TDJNM3G  E-COSMOS 5V 1.2W Portable Flexible USB LED Lig...
# ...

# %%
dd["rating"].sort_values()
# Out:
# 1309      2
# 1243    2.3
# 1356    2.6
# 1286    2.8
# 545     2.8
#        ...
# 1145    4.8
# 324     5.0
# 775     5.0
# 174     5.0
# 1279      |
# Name: rating, Length: 1465, dtype: object

# %%
c[d.index(max(d))]
# Out:
# 'Computers&Accessories|Accessories&Peripherals|Cables&Accessories|CableConnectionProtectors'

# %%
dd
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %%
df["discounted_price"].max()
# Out:
# '₹999'

# %%
s=dict()
for i in dd["category"]:
    s[i]=dd["category"].count(i)
s
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_456\1380549193.py:3: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. ser.count(level=1) should use ser.groupby(level=1).count().
#   s[i]=dd["category"].count(i)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [101], in <cell line: 2>()
#       1 s=dict()
#       2 for i in dd["category"]:
# ----> 3     s[i]=dd["category"].count(i)
#       4 s
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1976, in Series.count(self, level)
#    1968     warnings.warn(
#    1969         "Using the level keyword in DataFrame and Series aggregations is "
#    1970         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#    1973         stacklevel=find_stack_level(),
#    1974     )
# ...

# %%
df.nunique()
# Out:
# product_id             1351
# product_name           1337
# category                211
# discounted_price        550
# actual_price            449
# discount_percentage      92
# rating                   28
# rating_count           1143
# about_product          1293
# user_id                1194
# user_name              1194
# review_id              1194
# review_title           1194
# review_content         1212
# img_link               1412
# product_link           1465
# dtype: int64

# %%
for i in range(1465):
    df["discounted_price"][i]=df["discounted_price"][i].replace('₹',"")

# %%
df["discounted_price"][1154]
# Out:
# '3569'

# %%
for i in range(1465):
    df["discounted_price"][i]=df["discounted_price"][i].replace('₹',"")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
#       1 for i in range(1465):
# ----> 2     x=int(df["discounted_price"][i])
#       3     df["discounted_price"][i]=x
#
# ValueError: invalid literal for int() with base 10: '176.63'

# %%
df['discounted_price'] = df['discounted_price'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 df['discounted_price'] = df['discounted_price'].astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
1. head(): view the first few rows of a data frame
2. tail(): view the last few rows of a data frame
3. sort_values(): sort data frame by one or more columns
4. groupby(): group data frame by one or more columns
5. describe(): generate descriptive statistics for each column
6. sum(): calculate the sum of all values in a data frame
7. mean(): calculate the mean of all values in a data frame
8. min(): calculate the minimum value in a data frame
9. max(): calculate the maximum value in a data frame
10. count(): count the number of values in a data frame
11. drop(): remove specified columns or rows from a data frame
12. merge(): join two data frames on a common column or index
13. reset_index(): reset the index of a data frame
14. apply(): apply a function to each row or column in a data frame
15. melt(): reshape a data frame from long to wide format
16. pivot_table(): generate a data frame with a multi-level index
# Out:
#   Cell In[30], line 1
#     1. head(): view the first few rows of a data frame
#        ^
# SyntaxError: invalid syntax
